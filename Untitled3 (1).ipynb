# %%
#import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# listings dataset contains  Listings data for Austin
df=pd.read_csv('listings(3).csv')

# %%
df
# Out:
#                        id                                               name  \
# 0                    5456  Guesthouse in Austin · ★4.84 · 1 bedroom · 2 b...
# 1                  324480  Rental unit in Austin · 1 bedroom · 1 bed · 1 ...
# 2                    5769  Home in Austin · ★4.90 · 1 bedroom · 1 bed · 1...
# 3                  325889  Home in Austin · ★4.75 · 5 bedrooms · 6 beds ·...
# 4                    6413  Guesthouse in Austin · ★4.97 · Studio · 1 bed ...
# ...                   ...                                                ...
# 14689  910177330142638286  Home in Austin · ★New · 4 bedrooms · 5 beds · ...
# 14690  910180069136761621  Home in Austin · ★New · 1 bedroom · 1 bed · 1 ...
# 14691  910189933809989674  Home in Austin · ★New · 3 bedrooms · 3 beds · ...
# 14692  910204625611302482  Home in Austin · ★New · 2 bedrooms · 2 beds · ...
# 14693  910390262608850590  Home in Austin · ★New · 1 bedroom · 1 bed · 1 ...
#
#          host_id  host_name  neighbourhood_group  neighbourhood   latitude  \
# 0           8028     Sylvia                  NaN          78702  30.260570
# 1        1660476       Mark                  NaN          78705  30.299050
# 2           8186  Elizabeth                  NaN          78729  30.456970
# 3        1666874      Brian                  NaN          78704  30.245830
# 4          13879       Todd                  NaN          78704  30.248850
# ...          ...        ...                  ...            ...        ...
# 14689    5506864      Aymee                  NaN          78733  30.345020
# 14690  508303355    Gregory                  NaN          78721  30.280429
# 14691    9578079      Bonny                  NaN          78702  30.256408
# 14692    9578079      Bonny                  NaN          78702  30.256694
# 14693   28782498       Eric                  NaN          78704  30.258360
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0     -97.734410  Entire home/apt    107               2                648
# 1     -97.738810  Entire home/apt     99              30                  1
# 2     -97.784220     Private room     42               1                285
# 3     -97.754720  Entire home/apt    549               3                 89
# 4     -97.735870  Entire home/apt    109              30                122
# ...          ...              ...    ...             ...                ...
# 14689 -97.872840  Entire home/apt    521               2                  0
# 14690 -97.681119  Entire home/apt     68              21                  0
# 14691 -97.732358  Entire home/apt    296               1                  0
# 14692 -97.732911  Entire home/apt    223               1                  0
# 14693 -97.765830     Private room     65              20                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2023-06-04               3.73                               1
# 1      2022-09-20               0.11                               2
# 2      2023-06-03               1.78                               1
# 3      2023-05-29               0.65                               1
# 4      2022-10-17               0.74                               1
# ...           ...                ...                             ...
# 14689         NaN                NaN                               2
# 14690         NaN                NaN                               1
# 14691         NaN                NaN                               5
# 14692         NaN                NaN                               5
# 14693         NaN                NaN                               2
#
#        availability_365  number_of_reviews_ltm  license
# 0                   341                     45      NaN
# 1                   363                      1      NaN
# 2                     0                     21      NaN
# 3                   343                     22      NaN
# 4                     0                      4      NaN
# ...                 ...                    ...      ...
# 14689               363                      0      NaN
# 14690               327                      0      NaN
# 14691                82                      0      NaN
# 14692                87                      0      NaN
# 14693               269                      0      NaN
#
# [14694 rows x 18 columns]

# %%
#Data Description & statistcs Information
df.describe()
# Out:
#                  id       host_id  neighbourhood_group  neighbourhood  \
# count  1.469400e+04  1.469400e+04                  0.0   14694.000000
# mean   3.042378e+17  1.421518e+08                  NaN   78724.456853
# std    3.713878e+17  1.559583e+08                  NaN      20.662067
# min    5.456000e+03  2.300000e+01                  NaN   78701.000000
# 25%    2.363161e+07  1.611946e+07                  NaN   78704.000000
# 50%    5.079177e+07  7.113040e+07                  NaN   78723.000000
# 75%    7.128158e+17  2.445805e+08                  NaN   78745.000000
# max    9.109676e+17  5.188309e+08                  NaN   78759.000000
#
#            latitude     longitude         price  minimum_nights  \
# count  14694.000000  14694.000000  14694.000000    14694.000000
# mean      30.281540    -97.750159    268.724581        7.756840
# std        0.064605      0.062954    569.682846       27.935235
# min       30.078440    -98.056630      0.000000        1.000000
# 25%       30.242422    -97.768933     94.000000        1.000000
# 50%       30.269355    -97.740617    150.000000        2.000000
# 75%       30.309130    -97.716950    260.000000        3.000000
# max       30.515980    -97.560620  20000.000000     1124.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       14694.000000       11727.000000                    14694.000000
# mean           37.133048           1.604755                       12.997006
# std            78.488266           1.757701                       29.550244
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.290000                        1.000000
# 50%             9.000000           1.010000                        2.000000
# 75%            36.000000           2.380000                        7.000000
# max          1124.000000          27.180000                      175.000000
#
#        availability_365  number_of_reviews_ltm  license
# count      14694.000000           14694.000000      0.0
# mean         153.145229              10.733565      NaN
# std          136.530839              17.337812      NaN
# min            0.000000               0.000000      NaN
# 25%            0.000000               0.000000      NaN
# 50%          124.000000               3.000000      NaN
# 75%          302.000000              15.000000      NaN
# max          365.000000             280.000000      NaN

# %%
# checking the datatypes of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14694 entries, 0 to 14693
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14694 non-null  int64
#  1   name                            14694 non-null  object
#  2   host_id                         14694 non-null  int64
#  3   host_name                       14692 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   14694 non-null  int64
#  6   latitude                        14694 non-null  float64
#  7   longitude                       14694 non-null  float64
#  8   room_type                       14694 non-null  object
#  9   price                           14694 non-null  int64
#  10  minimum_nights                  14694 non-null  int64
#  11  number_of_reviews               14694 non-null  int64
#  12  last_review                     11727 non-null  object
#  13  reviews_per_month               11727 non-null  float64
#  14  calculated_host_listings_count  14694 non-null  int64
#  15  availability_365                14694 non-null  int64
#  16  number_of_reviews_ltm           14694 non-null  int64
#  17  license                         0 non-null      float64
# dtypes: float64(5), int64(9), object(4)
# memory usage: 2.0+ MB

# %%
# checking the number of Missing  values in each column 
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             2
# neighbourhood_group               14694
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        2967
# reviews_per_month                  2967
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           14694
# dtype: int64

# %%
#Delete unnecessary columns  
df.drop(['latitude','longitude','last_review','reviews_per_month','license','neighbourhood_group'],axis=1,inplace=True)

# %%
df
# Out:
#                        id                                               name  \
# 0                    5456  Guesthouse in Austin · ★4.84 · 1 bedroom · 2 b...
# 1                  324480  Rental unit in Austin · 1 bedroom · 1 bed · 1 ...
# 2                    5769  Home in Austin · ★4.90 · 1 bedroom · 1 bed · 1...
# 3                  325889  Home in Austin · ★4.75 · 5 bedrooms · 6 beds ·...
# 4                    6413  Guesthouse in Austin · ★4.97 · Studio · 1 bed ...
# ...                   ...                                                ...
# 14689  910177330142638286  Home in Austin · ★New · 4 bedrooms · 5 beds · ...
# 14690  910180069136761621  Home in Austin · ★New · 1 bedroom · 1 bed · 1 ...
# 14691  910189933809989674  Home in Austin · ★New · 3 bedrooms · 3 beds · ...
# 14692  910204625611302482  Home in Austin · ★New · 2 bedrooms · 2 beds · ...
# 14693  910390262608850590  Home in Austin · ★New · 1 bedroom · 1 bed · 1 ...
#
#          host_id  host_name  neighbourhood        room_type  price  \
# 0           8028     Sylvia          78702  Entire home/apt    107
# 1        1660476       Mark          78705  Entire home/apt     99
# 2           8186  Elizabeth          78729     Private room     42
# 3        1666874      Brian          78704  Entire home/apt    549
# 4          13879       Todd          78704  Entire home/apt    109
# ...          ...        ...            ...              ...    ...
# 14689    5506864      Aymee          78733  Entire home/apt    521
# 14690  508303355    Gregory          78721  Entire home/apt     68
# 14691    9578079      Bonny          78702  Entire home/apt    296
# 14692    9578079      Bonny          78702  Entire home/apt    223
# 14693   28782498       Eric          78704     Private room     65
#
#        minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                   2                648                               1
# 1                  30                  1                               2
# 2                   1                285                               1
# 3                   3                 89                               1
# 4                  30                122                               1
# ...               ...                ...                             ...
# 14689               2                  0                               2
# 14690              21                  0                               1
# 14691               1                  0                               5
# 14692               1                  0                               5
# 14693              20                  0                               2
#
#        availability_365  number_of_reviews_ltm
# 0                   341                     45
# 1                   363                      1
# 2                     0                     21
# 3                   343                     22
# 4                     0                      4
# ...                 ...                    ...
# 14689               363                      0
# 14690               327                      0
# 14691                82                      0
# 14692                87                      0
# 14693               269                      0
#
# [14694 rows x 12 columns]

# %%
#learn about different hosts 
host_areas =df.groupby(['host_name'])['calculated_host_listings_count'].max().reset_index()
host_areas.sort_values(by='calculated_host_listings_count',ascending=False)
# Out:
#           host_name  calculated_host_listings_count
# 1819        Landing                             175
# 406      Blueground                             140
# 1036        Evonify                             111
# 3210   Vacasa Texas                              94
# 2105         Martin                              87
# ...             ...                             ...
# 1325          Irene                               1
# 1326          Irina                               1
# 1327  Iris And Eyal                               1
# 1328           Irma                               1
# 3369            Zvi                               1
#
# [3370 rows x 2 columns]

# %% [markdown]
# We find that Host name Landing has listed highest number of listings in Manhattan followed by Blueground

# %%
#room type and their prices according to name of Hotel
room_price_area_wise = df.groupby(['name','room_type'])['price'].max().reset_index()
room_price_area_wise.sort_values(by='price', ascending=False)
# Out:
#                                                    name        room_type  \
# 3855    Hotel in Austin · 2 bedrooms · 2 beds · 2 baths     Private room
# 3853  Hotel in Austin · 1 bedroom · 1 bed · 1 privat...     Private room
# 5421  Villa in Austin · 6 bedrooms · 6 beds · 8.5 baths  Entire home/apt
# 1505     Home in Austin · 3 bedrooms · 5 beds · 3 baths  Entire home/apt
# 1479   Home in Austin · 3 bedrooms · 2 beds · 2.5 baths  Entire home/apt
# ...                                                 ...              ...
# 4718  Rental unit in Austin · ★4.92 · 1 bedroom · 1 ...      Shared room
# 342       Camper/RV in Austin · ★4.95 · 1 bed · 0 baths  Entire home/apt
# 1004  Guest suite in Austin · Studio · 1 bed · 1 pri...     Private room
# 3858                           Hotel in Austin · Studio       Hotel room
# 3872                  Hotel in West Lake Hills · Studio       Hotel room
#
#       price
# 3855  20000
# 3853  20000
# 5421  10450
# 1505  10309
# 1479  10000
# ...     ...
# 4718     17
# 342      10
# 1004      5
# 3858      0
# 3872      0
#
# [5479 rows x 3 columns]

# %%
#Number of Reviews in terms of host name
area_reviews = df.groupby(['host_name'])['number_of_reviews'].max().reset_index()
area_reviews
# Out:
#                   host_name  number_of_reviews
# 0            3 Little Birds                 35
# 1     A Stay Above The Rest                 51
# 2                        A.                 10
# 3               ATX Rentals                199
# 4                     Aalia                  0
# ...                     ...                ...
# 3365                 Zocimo                  0
# 3366                    Zoe                368
# 3367                 Zohaib                  2
# 3368                    Zoi                  0
# 3369                    Zvi                  5
#
# [3370 rows x 2 columns]

# %%
#Number of Reviews VS Price
price_area = df.groupby(['price'])['number_of_reviews'].max().reset_index()
price_area.head(10)
# Out:
#    price  number_of_reviews
# 0      0                  0
# 1      1                  2
# 2      5                  1
# 3     10                 23
# 4     15                 10
# 5     17                 13
# 6     18                  3
# 7     19                 21
# 8     20                 69
# 9     22                  0

# %%
price_list = price_area['price']
review = price_area['number_of_reviews']
fig =plt.figure(figsize =(10,5))

plt.scatter(price_list, review)
plt.xlabel('Price')
plt.ylabel('Number of reviews')
plt.title('Number of Reviews VS Price')
plt.show()

# %% [markdown]
# From above visualization we can say that most number of people like to stay in less price and their reviews are higher in those areas

# %%
#hosts are the busiest in terms of reviews
busy_hosts = df.groupby(['host_id','host_name','room_type'])['number_of_reviews'].max().reset_index()
busy_hosts = busy_hosts.sort_values(by = 'number_of_reviews', ascending =False).head(10)
busy_hosts
# Out:
#        host_id    host_name        room_type  number_of_reviews
# 1335   5152543     Marcella  Entire home/apt               1124
# 278     740347        Chris  Entire home/apt               1113
# 102     272156         Lois  Entire home/apt                982
# 962    3353143  Anna & Chad  Entire home/apt                962
# 353     989596         John  Entire home/apt                958
# 1030   3626574         Bill  Entire home/apt                857
# 608    1770424        Jason  Entire home/apt                833
# 34       72957      Tiffany  Entire home/apt                832
# 5608  88566861         Kasa  Entire home/apt                826
# 31       61292        Jeany  Entire home/apt                820

# %%
name_hosts = busy_hosts['host_name']
review_got = busy_hosts['number_of_reviews']

fig = plt.figure(figsize =(10,5))

plt.bar(name_hosts,review_got, color ='purple', width =0.5)
plt.xlabel('Name of the Host')
plt.ylabel('Review')
plt.title("Busiest Host in terms of reviews")
plt.show()

# %% [markdown]
# We have found Busiest hosts:
#
#     marcella
#     chris
#     lois
#     anna&chead
#
# Because these hosts listed their room type as Entire home  which is preferred by most number of people and also their reviews are higher.

# %%
#Hosts are charging higher price
Highest_price= df.groupby(['host_id','host_name','room_type'])['price'].max().reset_index()
Highest_price= Highest_price.sort_values(by = 'price', ascending =False).head(10)
Highest_price
# Out:
#         host_id          host_name        room_type  price
# 7808  326084746          Suiteness     Private room  20000
# 7138  210733801     Above Vacation  Entire home/apt  10450
# 6217  124060715             Evolve  Entire home/apt  10309
# 147      384732             Andres  Entire home/apt  10000
# 6001  111566801           Jonathon  Entire home/apt  10000
# 7732  304514040  East Austin Hotel     Private room  10000
# 7822  330222299             Arrive     Private room  10000
# 3032   22773046                Eli  Entire home/apt  10000
# 5358   74821547           Hai-Shan     Private room   9998
# 5089   65209843             Robert  Entire home/apt   9143

# %%
tra_areas = df.groupby(['room_type'])['minimum_nights'].count().reset_index()
traffic_areas = traffic_areas.sort_values(by ='minimum_nights',ascending = False).head(20)
traffic_areas
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt           12127
# 2     Private room            2443
# 3      Shared room             116
# 1       Hotel room               8

# %%
#diffrent types of rooms availabe
df['room_type'].value_counts().plot(
    kind='bar',
    xlabel='Room type',
    ylabel='Frequency',
    title='No. of each room type'
);

# %%
#Price for diffrent types of room 
name_of_host = Highest_price ['host_name']
price_charge = Highest_price['price']

fig = plt.figure(figsize =(10,5))

plt.bar(name_of_host,price_charge , color ='orange', width =0.5)
plt.xlabel('Name of the Host')
plt.ylabel('Price')
plt.title("Hosts with maximum price charges")
plt.show()

# %%
sns.histplot(data=df,x='price');

# %%
price_q1 = df['price'].quantile(0.25) 
price_q3 = df['price'].quantile(0.75)
price_iqr = price_q3 - price_q1
df_= df[df['price'].between(left=price_q1-1.5 * price_iqr, right=price_q3+1.5*price_iqr)]

# %%
sns.histplot(data=df_,x='price');

# %%
sns.boxplot(data=df_,x='price', y='room_type');

# %%
sns.kdeplot(df_,x='price', hue='room_type', cut=0)
sns.set(rc={"figure.figsize":(8, 8)})
plt.show()

# %%
sns.lineplot(data=df_, x='room_type',y='price');

# %%
#Room availability
df_['availability_365'].nunique(), df['availability_365'].min(),df['availability_365'].max()
# Out:
# (366, 0, 365)

# %%
sns.kdeplot(df_,x='availability_365',hue='room_type',cut=0);
# Out:
# C:\Users\mosta\AppData\Local\Temp\ipykernel_28336\2904613289.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df_,x='availability_365',hue='room_type',cut=0);

# %%
sns.boxplot(df_,y='availability_365',x='room_type')
# Out:
# <Axes: xlabel='room_type', ylabel='availability_365'>

# %%
#reviews for each room type
df_['number_of_reviews'].nunique(), df_['number_of_reviews'].min(),df_['number_of_reviews'].max()
# Out:
# (472, 0, 1124)

# %%
rev_q1 = df['number_of_reviews'].quantile(0.25)
rev_q3 = df['number_of_reviews'].quantile(0.75)
rev_iqr = rev_q3 - rev_q1
df_ = df_[df_['number_of_reviews'].between(left=rev_q1-1.5*rev_iqr, right=rev_q3+1.5*rev_iqr)]

# %%
sns.kdeplot(df_, x='number_of_reviews',hue='room_type',cut=0);

# %%
df_['minimum_nights'].nunique(),df['minimum_nights'].min(), df['minimum_nights'].max()
# Out:
# (59, 1, 1124)

# %%
areas_Traffic = traffic_areas['room_type']
room_stayed = traffic_areas['minimum_nights']

fig = plt.figure(figsize =(7,5))

plt.bar(areas_Traffic,room_stayed, color ="blue", width = 0.2)

plt.xlabel("Room Type")
plt.ylabel("Minimum Night")
plt.title("Traffic Areas based on Minimum Nights Booked")
plt.show()

# %%
mn_q1 = df['minimum_nights'].quantile(0.25)
mn_q3 = df['minimum_nights'].quantile(0.75)
mn_iqr = mn_q3 - mn_q1
df_ = df_[df_['minimum_nights'].between(left=mn_q1-1.5*mn_iqr, right=mn_q3+1.5*mn_iqr)]

# %%
sns.countplot(df_,x='minimum_nights',hue='room_type');

# %%
sns.barplot(df_,x='minimum_nights',y='price',hue='room_type')
# Out:
# <Axes: xlabel='minimum_nights', ylabel='price'>

# %%
#Number of reviews 
df_['number_of_reviews_ltm'].describe()
mr_q1 = df['number_of_reviews_ltm'].quantile(0.25)
mr_q3 = df['number_of_reviews_ltm'].quantile(0.75)
mr_iqr = mr_q3 - mr_q1
df_ = df_[df_['number_of_reviews_ltm'].between(left=mr_q1-1.5*mr_iqr, right=mr_q3+1.5*mr_iqr)]
df_['number_of_reviews_ltm'].hist();

# %%
sns.kdeplot(df_,x='number_of_reviews_ltm', hue='room_type',cut=0)
# Out:
# C:\Users\mosta\AppData\Local\Temp\ipykernel_28336\1506030171.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df_,x='number_of_reviews_ltm', hue='room_type',cut=0)
# <Axes: xlabel='number_of_reviews_ltm', ylabel='Density'>

# %%
sns.boxplot(df_,x='number_of_reviews', y='room_type')
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='room_type'>
